# %%
import pandas as pd

# %%
survey_raw_df=pd.read_csv('survey_results_public.csv')

# %%
survey_raw_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
#         Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0       NaN         13  Monthly        NaN            NaN             Germany
# 1       NaN         19      NaN        NaN            NaN      United Kingdom
# 2       NaN         15      NaN        NaN            NaN  Russian Federation
# 3      25.0         18      NaN        NaN            NaN             Albania
# 4      31.0         16      NaN        NaN            NaN       United States
# ...     ...        ...      ...        ...            ...                 ...
# 64456   NaN         16      NaN        NaN            NaN       United States
# 64457   NaN        NaN      NaN        NaN            NaN             Morocco
# 64458   NaN        NaN      NaN        NaN            NaN            Viet Nam
# 64459   NaN        NaN      NaN        NaN            NaN              Poland
# 64460   NaN        NaN      NaN        NaN            NaN               Spain
#
#          CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# 0       European Euro  ...  Neither easy nor difficult  Appropriate in length
# 1      Pound sterling  ...                         NaN                    NaN
# 2                 NaN  ...  Neither easy nor difficult  Appropriate in length
# 3        Albanian lek  ...                         NaN                    NaN
# 4                 NaN  ...                        Easy              Too short
# ...               ...  ...                         ...                    ...
# 64456             NaN  ...                         NaN                    NaN
# 64457             NaN  ...                         NaN                    NaN
# 64458             NaN  ...                         NaN                    NaN
# 64459             NaN  ...                         NaN                    NaN
# 64460             NaN  ...                         NaN                    NaN
#
#       Trans                                     UndergradMajor  \
# 0        No  Computer science, computer engineering, or sof...
# 1       NaN  Computer science, computer engineering, or sof...
# 2       NaN                                                NaN
# 3        No  Computer science, computer engineering, or sof...
# 4        No  Computer science, computer engineering, or sof...
# ...     ...                                                ...
# 64456   NaN  Computer science, computer engineering, or sof...
# 64457   NaN                                                NaN
# 64458   NaN                                                NaN
# 64459   NaN                                                NaN
# 64460   NaN  Computer science, computer engineering, or sof...
#
#             WebframeDesireNextYear                      WebframeWorkedWith  \
# 0                     ASP.NET Core                    ASP.NET;ASP.NET Core
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4             Django;Ruby on Rails                           Ruby on Rails
# ...                            ...                                     ...
# 64456                          NaN                                     NaN
# 64457                          NaN                                     NaN
# 64458                          NaN                                     NaN
# 64459  Angular;Angular.js;React.js                                     NaN
# 64460          ASP.NET Core;jQuery  Angular;Angular.js;ASP.NET Core;jQuery
#
#                                   WelcomeChange WorkWeekHrs YearsCode  \
# 0       Just as welcome now as I felt last year        50.0        36
# 1      Somewhat more welcome now than last year         NaN         7
# 2      Somewhat more welcome now than last year         NaN         4
# 3      Somewhat less welcome now than last year        40.0         7
# 4       Just as welcome now as I felt last year         NaN        15
# ...                                         ...         ...       ...
# 64456                                       NaN         NaN        10
# 64457                                       NaN         NaN       NaN
# 64458                                       NaN         NaN       NaN
# 64459                                       NaN         NaN       NaN
# 64460                                       NaN         NaN       NaN
#
#            YearsCodePro
# 0                    27
# 1                     4
# 2                   NaN
# 3                     4
# 4                     8
# ...                 ...
# 64456  Less than 1 year
# 64457               NaN
# 64458               NaN
# 64459               NaN
# 64460               NaN
#
# [64461 rows x 61 columns]

# %%
survey_raw_df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
#        'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
#        'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode',
#        'YearsCodePro'],
#       dtype='object')

# %%
schema_df=pd.read_csv('survey_results_schema.csv')

# %%
schema_df
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
selected_columns = [
    # Demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',
    # Programming experience
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',
    # Employment
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt'
]

# %%
len(selected_columns)
# Out:
# 20

# %%
survey_df=survey_raw_df[selected_columns].copy()

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64457                                              NaN
# 64458                        Primary/elementary school
# 64459                                              NaN
# 64460       Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                           UndergradMajor Hobbyist Age1stCode  \
# 0      Computer science, computer engineering, or sof...      Yes         13
# 1      Computer science, computer engineering, or sof...       No         19
# 2                                                    NaN      Yes         15
# 3      Computer science, computer engineering, or sof...      Yes         18
# 4      Computer science, computer engineering, or sof...      Yes         16
# ...                                                  ...      ...        ...
# 64456  Computer science, computer engineering, or sof...      Yes         16
# 64457                                                NaN      Yes        NaN
# 64458                                                NaN      Yes        NaN
# 64459                                                NaN      Yes        NaN
# 64460  Computer science, computer engineering, or sof...      Yes        NaN
#
#       YearsCode      YearsCodePro  \
# 0            36                27
# 1             7                 4
# 2             4               NaN
# 3             7                 4
# 4            15                 8
# ...         ...               ...
# 64456        10  Less than 1 year
# 64457       NaN               NaN
# 64458       NaN               NaN
# 64459       NaN               NaN
# 64460       NaN               NaN
#
#                                       LanguageWorkedWith  \
# 0                                 C#;HTML/CSS;JavaScript
# 1                                       JavaScript;Swift
# 2                               Objective-C;Python;Swift
# 3                                                    NaN
# 4                                      HTML/CSS;Ruby;SQL
# ...                                                  ...
# 64456                                                NaN
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                NaN
# 64459                                           HTML/CSS
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL
#
#                                   LanguageDesireNextYear       NEWLearn  \
# 0                                 C#;HTML/CSS;JavaScript    Once a year
# 1                                           Python;Swift    Once a year
# 2                               Objective-C;Python;Swift  Once a decade
# 3                                                    NaN    Once a year
# 4                                        Java;Ruby;Scala    Once a year
# ...                                                  ...            ...
# 64456                                                NaN  Once a decade
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...            NaN
# 64458                                                NaN            NaN
# 64459                           HTML/CSS;Java;JavaScript    Once a year
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL    Once a year
#
#                                                 NEWStuck  \
# 0      Visit Stack Overflow;Go for a walk or other ph...
# 1      Visit Stack Overflow;Go for a walk or other ph...
# 2                                                    NaN
# 3                                                    NaN
# 4      Call a coworker or friend;Visit Stack Overflow...
# ...                                                  ...
# 64456                          Call a coworker or friend
# 64457                                                NaN
# 64458                                                NaN
# 64459     Call a coworker or friend;Visit Stack Overflow
# 64460  Meditate;Visit Stack Overflow;Go for a walk or...
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Employed full-time
# 2                                                    NaN
# 3                                                    NaN
# 4                                     Employed full-time
# ...                                                  ...
# 64456                                 Employed full-time
# 64457                                 Employed full-time
# 64458                                                NaN
# 64459                                 Employed full-time
# 64460                                 Employed full-time
#
#                                                  DevType  WorkWeekHrs  \
# 0      Developer, desktop or enterprise applications;...         50.0
# 1                Developer, full-stack;Developer, mobile          NaN
# 2                                                    NaN          NaN
# 3                                                    NaN         40.0
# 4                                                    NaN          NaN
# ...                                                  ...          ...
# 64456                                Senior executive/VP          NaN
# 64457                                                NaN          NaN
# 64458                                                NaN          NaN
# 64459                                                NaN          NaN
# 64460                                                NaN          NaN
#
#                       JobSat  \
# 0         Slightly satisfied
# 1          Very dissatisfied
# 2                        NaN
# 3      Slightly dissatisfied
# 4                        NaN
# ...                      ...
# 64456                    NaN
# 64457                    NaN
# 64458                    NaN
# 64459                    NaN
# 64460                    NaN
#
#                                               JobFactors  \
# 0      Languages, frameworks, and other technologies ...
# 1                                                    NaN
# 2                                                    NaN
# 3      Flex time or a flexible schedule;Office enviro...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                              NEWOvertime  \
# 0                       Often: 1-2 days per week or more
# 1                                                    NaN
# 2                                                    NaN
# 3      Occasionally: 1-2 days per quarter but less th...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                 NEWEdImpt
# 0                        Fairly important
# 1                        Fairly important
# 2                                     NaN
# 3      Not at all important/not necessary
# 4                          Very important
# ...                                   ...
# 64456                      Very important
# 64457                                 NaN
# 64458                                 NaN
# 64459                                 NaN
# 64460                Critically important
#
# [64461 rows x 20 columns]

# %%
survey_df.shape
# Out:
# (64461, 20)

# %%
survey_df.info
# Out:
# <bound method DataFrame.info of                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64457                                              NaN
# 64458                        Primary/elementary school
# 64459                                              NaN
# 64460       Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                           UndergradMajor Hobbyist Age1stCode  \
# 0      Computer science, computer engineering, or sof...      Yes         13
# 1      Computer science, computer engineering, or sof...       No         19
# 2                                                    NaN      Yes         15
# 3      Computer science, computer engineering, or sof...      Yes         18
# 4      Computer science, computer engineering, or sof...      Yes         16
# ...                                                  ...      ...        ...
# 64456  Computer science, computer engineering, or sof...      Yes         16
# 64457                                                NaN      Yes        NaN
# 64458                                                NaN      Yes        NaN
# 64459                                                NaN      Yes        NaN
# 64460  Computer science, computer engineering, or sof...      Yes        NaN
#
#       YearsCode      YearsCodePro  \
# 0            36                27
# 1             7                 4
# 2             4               NaN
# 3             7                 4
# 4            15                 8
# ...         ...               ...
# 64456        10  Less than 1 year
# 64457       NaN               NaN
# 64458       NaN               NaN
# 64459       NaN               NaN
# 64460       NaN               NaN
#
#                                       LanguageWorkedWith  \
# 0                                 C#;HTML/CSS;JavaScript
# 1                                       JavaScript;Swift
# 2                               Objective-C;Python;Swift
# 3                                                    NaN
# 4                                      HTML/CSS;Ruby;SQL
# ...                                                  ...
# 64456                                                NaN
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                NaN
# 64459                                           HTML/CSS
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL
#
#                                   LanguageDesireNextYear       NEWLearn  \
# 0                                 C#;HTML/CSS;JavaScript    Once a year
# 1                                           Python;Swift    Once a year
# 2                               Objective-C;Python;Swift  Once a decade
# 3                                                    NaN    Once a year
# 4                                        Java;Ruby;Scala    Once a year
# ...                                                  ...            ...
# 64456                                                NaN  Once a decade
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...            NaN
# 64458                                                NaN            NaN
# 64459                           HTML/CSS;Java;JavaScript    Once a year
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL    Once a year
#
#                                                 NEWStuck  \
# 0      Visit Stack Overflow;Go for a walk or other ph...
# 1      Visit Stack Overflow;Go for a walk or other ph...
# 2                                                    NaN
# 3                                                    NaN
# 4      Call a coworker or friend;Visit Stack Overflow...
# ...                                                  ...
# 64456                          Call a coworker or friend
# 64457                                                NaN
# 64458                                                NaN
# 64459     Call a coworker or friend;Visit Stack Overflow
# 64460  Meditate;Visit Stack Overflow;Go for a walk or...
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Employed full-time
# 2                                                    NaN
# 3                                                    NaN
# 4                                     Employed full-time
# ...                                                  ...
# 64456                                 Employed full-time
# 64457                                 Employed full-time
# 64458                                                NaN
# 64459                                 Employed full-time
# 64460                                 Employed full-time
#
#                                                  DevType  WorkWeekHrs  \
# 0      Developer, desktop or enterprise applications;...         50.0
# 1                Developer, full-stack;Developer, mobile          NaN
# 2                                                    NaN          NaN
# 3                                                    NaN         40.0
# 4                                                    NaN          NaN
# ...                                                  ...          ...
# 64456                                Senior executive/VP          NaN
# 64457                                                NaN          NaN
# 64458                                                NaN          NaN
# 64459                                                NaN          NaN
# 64460                                                NaN          NaN
#
#                       JobSat  \
# 0         Slightly satisfied
# 1          Very dissatisfied
# 2                        NaN
# 3      Slightly dissatisfied
# 4                        NaN
# ...                      ...
# 64456                    NaN
# 64457                    NaN
# 64458                    NaN
# 64459                    NaN
# 64460                    NaN
#
#                                               JobFactors  \
# 0      Languages, frameworks, and other technologies ...
# 1                                                    NaN
# 2                                                    NaN
# 3      Flex time or a flexible schedule;Office enviro...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                              NEWOvertime  \
# 0                       Often: 1-2 days per week or more
# 1                                                    NaN
# 2                                                    NaN
# 3      Occasionally: 1-2 days per quarter but less th...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                 NEWEdImpt
# 0                        Fairly important
# 1                        Fairly important
# 2                                     NaN
# 3      Not at all important/not necessary
# 4                          Very important
# ...                                   ...
# 64456                      Very important
# 64457                                 NaN
# 64458                                 NaN
# 64459                                 NaN
# 64460                Critically important
#
# [64461 rows x 20 columns]>

# %%
survey_df.describe
# Out:
# <bound method NDFrame.describe of                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64457                                              NaN
# 64458                        Primary/elementary school
# 64459                                              NaN
# 64460       Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                           UndergradMajor Hobbyist Age1stCode  \
# 0      Computer science, computer engineering, or sof...      Yes         13
# 1      Computer science, computer engineering, or sof...       No         19
# 2                                                    NaN      Yes         15
# 3      Computer science, computer engineering, or sof...      Yes         18
# 4      Computer science, computer engineering, or sof...      Yes         16
# ...                                                  ...      ...        ...
# 64456  Computer science, computer engineering, or sof...      Yes         16
# 64457                                                NaN      Yes        NaN
# 64458                                                NaN      Yes        NaN
# 64459                                                NaN      Yes        NaN
# 64460  Computer science, computer engineering, or sof...      Yes        NaN
#
#       YearsCode      YearsCodePro  \
# 0            36                27
# 1             7                 4
# 2             4               NaN
# 3             7                 4
# 4            15                 8
# ...         ...               ...
# 64456        10  Less than 1 year
# 64457       NaN               NaN
# 64458       NaN               NaN
# 64459       NaN               NaN
# 64460       NaN               NaN
#
#                                       LanguageWorkedWith  \
# 0                                 C#;HTML/CSS;JavaScript
# 1                                       JavaScript;Swift
# 2                               Objective-C;Python;Swift
# 3                                                    NaN
# 4                                      HTML/CSS;Ruby;SQL
# ...                                                  ...
# 64456                                                NaN
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                NaN
# 64459                                           HTML/CSS
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL
#
#                                   LanguageDesireNextYear       NEWLearn  \
# 0                                 C#;HTML/CSS;JavaScript    Once a year
# 1                                           Python;Swift    Once a year
# 2                               Objective-C;Python;Swift  Once a decade
# 3                                                    NaN    Once a year
# 4                                        Java;Ruby;Scala    Once a year
# ...                                                  ...            ...
# 64456                                                NaN  Once a decade
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...            NaN
# 64458                                                NaN            NaN
# 64459                           HTML/CSS;Java;JavaScript    Once a year
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL    Once a year
#
#                                                 NEWStuck  \
# 0      Visit Stack Overflow;Go for a walk or other ph...
# 1      Visit Stack Overflow;Go for a walk or other ph...
# 2                                                    NaN
# 3                                                    NaN
# 4      Call a coworker or friend;Visit Stack Overflow...
# ...                                                  ...
# 64456                          Call a coworker or friend
# 64457                                                NaN
# 64458                                                NaN
# 64459     Call a coworker or friend;Visit Stack Overflow
# 64460  Meditate;Visit Stack Overflow;Go for a walk or...
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Employed full-time
# 2                                                    NaN
# 3                                                    NaN
# 4                                     Employed full-time
# ...                                                  ...
# 64456                                 Employed full-time
# 64457                                 Employed full-time
# 64458                                                NaN
# 64459                                 Employed full-time
# 64460                                 Employed full-time
#
#                                                  DevType  WorkWeekHrs  \
# 0      Developer, desktop or enterprise applications;...         50.0
# 1                Developer, full-stack;Developer, mobile          NaN
# 2                                                    NaN          NaN
# 3                                                    NaN         40.0
# 4                                                    NaN          NaN
# ...                                                  ...          ...
# 64456                                Senior executive/VP          NaN
# 64457                                                NaN          NaN
# 64458                                                NaN          NaN
# 64459                                                NaN          NaN
# 64460                                                NaN          NaN
#
#                       JobSat  \
# 0         Slightly satisfied
# 1          Very dissatisfied
# 2                        NaN
# 3      Slightly dissatisfied
# 4                        NaN
# ...                      ...
# 64456                    NaN
# 64457                    NaN
# 64458                    NaN
# 64459                    NaN
# 64460                    NaN
#
#                                               JobFactors  \
# 0      Languages, frameworks, and other technologies ...
# 1                                                    NaN
# 2                                                    NaN
# 3      Flex time or a flexible schedule;Office enviro...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                              NEWOvertime  \
# 0                       Often: 1-2 days per week or more
# 1                                                    NaN
# 2                                                    NaN
# 3      Occasionally: 1-2 days per quarter but less th...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                 NEWEdImpt
# 0                        Fairly important
# 1                        Fairly important
# 2                                     NaN
# 3      Not at all important/not necessary
# 4                          Very important
# ...                                   ...
# 64456                      Very important
# 64457                                 NaN
# 64458                                 NaN
# 64459                                 NaN
# 64460                Critically important
#
# [64461 rows x 20 columns]>

# %%
survey_df['Age1stCode']=pd.to_numeric(survey_df.Age1stCode, errors='coerce')
survey_df['YearsCode']=pd.to_numeric(survey_df.YearsCode, errors='coerce')
survey_df['YearsCodePro']=pd.to_numeric(survey_df.YearsCodePro, errors='coerce')

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64457                                              NaN
# 64458                        Primary/elementary school
# 64459                                              NaN
# 64460       Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                           UndergradMajor Hobbyist  Age1stCode  \
# 0      Computer science, computer engineering, or sof...      Yes        13.0
# 1      Computer science, computer engineering, or sof...       No        19.0
# 2                                                    NaN      Yes        15.0
# 3      Computer science, computer engineering, or sof...      Yes        18.0
# 4      Computer science, computer engineering, or sof...      Yes        16.0
# ...                                                  ...      ...         ...
# 64456  Computer science, computer engineering, or sof...      Yes        16.0
# 64457                                                NaN      Yes         NaN
# 64458                                                NaN      Yes         NaN
# 64459                                                NaN      Yes         NaN
# 64460  Computer science, computer engineering, or sof...      Yes         NaN
#
#        YearsCode  YearsCodePro  \
# 0           36.0          27.0
# 1            7.0           4.0
# 2            4.0           NaN
# 3            7.0           4.0
# 4           15.0           8.0
# ...          ...           ...
# 64456       10.0           NaN
# 64457        NaN           NaN
# 64458        NaN           NaN
# 64459        NaN           NaN
# 64460        NaN           NaN
#
#                                       LanguageWorkedWith  \
# 0                                 C#;HTML/CSS;JavaScript
# 1                                       JavaScript;Swift
# 2                               Objective-C;Python;Swift
# 3                                                    NaN
# 4                                      HTML/CSS;Ruby;SQL
# ...                                                  ...
# 64456                                                NaN
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                NaN
# 64459                                           HTML/CSS
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL
#
#                                   LanguageDesireNextYear       NEWLearn  \
# 0                                 C#;HTML/CSS;JavaScript    Once a year
# 1                                           Python;Swift    Once a year
# 2                               Objective-C;Python;Swift  Once a decade
# 3                                                    NaN    Once a year
# 4                                        Java;Ruby;Scala    Once a year
# ...                                                  ...            ...
# 64456                                                NaN  Once a decade
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...            NaN
# 64458                                                NaN            NaN
# 64459                           HTML/CSS;Java;JavaScript    Once a year
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL    Once a year
#
#                                                 NEWStuck  \
# 0      Visit Stack Overflow;Go for a walk or other ph...
# 1      Visit Stack Overflow;Go for a walk or other ph...
# 2                                                    NaN
# 3                                                    NaN
# 4      Call a coworker or friend;Visit Stack Overflow...
# ...                                                  ...
# 64456                          Call a coworker or friend
# 64457                                                NaN
# 64458                                                NaN
# 64459     Call a coworker or friend;Visit Stack Overflow
# 64460  Meditate;Visit Stack Overflow;Go for a walk or...
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Employed full-time
# 2                                                    NaN
# 3                                                    NaN
# 4                                     Employed full-time
# ...                                                  ...
# 64456                                 Employed full-time
# 64457                                 Employed full-time
# 64458                                                NaN
# 64459                                 Employed full-time
# 64460                                 Employed full-time
#
#                                                  DevType  WorkWeekHrs  \
# 0      Developer, desktop or enterprise applications;...         50.0
# 1                Developer, full-stack;Developer, mobile          NaN
# 2                                                    NaN          NaN
# 3                                                    NaN         40.0
# 4                                                    NaN          NaN
# ...                                                  ...          ...
# 64456                                Senior executive/VP          NaN
# 64457                                                NaN          NaN
# 64458                                                NaN          NaN
# 64459                                                NaN          NaN
# 64460                                                NaN          NaN
#
#                       JobSat  \
# 0         Slightly satisfied
# 1          Very dissatisfied
# 2                        NaN
# 3      Slightly dissatisfied
# 4                        NaN
# ...                      ...
# 64456                    NaN
# 64457                    NaN
# 64458                    NaN
# 64459                    NaN
# 64460                    NaN
#
#                                               JobFactors  \
# 0      Languages, frameworks, and other technologies ...
# 1                                                    NaN
# 2                                                    NaN
# 3      Flex time or a flexible schedule;Office enviro...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                              NEWOvertime  \
# 0                       Often: 1-2 days per week or more
# 1                                                    NaN
# 2                                                    NaN
# 3      Occasionally: 1-2 days per quarter but less th...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                 NEWEdImpt
# 0                        Fairly important
# 1                        Fairly important
# 2                                     NaN
# 3      Not at all important/not necessary
# 4                          Very important
# ...                                   ...
# 64456                      Very important
# 64457                                 NaN
# 64458                                 NaN
# 64459                                 NaN
# 64460                Critically important
#
# [64461 rows x 20 columns]

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45446.000000  57473.000000  56784.000000  44133.000000  41151.000000
# mean      30.834111     15.476572     12.782051      8.869667     40.782174
# std        9.585392      5.114081      9.490657      7.759961     17.816383
# min        1.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %%
(survey_df.Age<10).sum()
# Out:
# 9

# %%
survey_df.drop(survey_df[survey_df.Age< 10].index, inplace=True)
survey_df.drop(survey_df[survey_df.Age> 100].index, inplace=True)

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64457                                              NaN
# 64458                        Primary/elementary school
# 64459                                              NaN
# 64460       Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                           UndergradMajor Hobbyist  Age1stCode  \
# 0      Computer science, computer engineering, or sof...      Yes        13.0
# 1      Computer science, computer engineering, or sof...       No        19.0
# 2                                                    NaN      Yes        15.0
# 3      Computer science, computer engineering, or sof...      Yes        18.0
# 4      Computer science, computer engineering, or sof...      Yes        16.0
# ...                                                  ...      ...         ...
# 64456  Computer science, computer engineering, or sof...      Yes        16.0
# 64457                                                NaN      Yes         NaN
# 64458                                                NaN      Yes         NaN
# 64459                                                NaN      Yes         NaN
# 64460  Computer science, computer engineering, or sof...      Yes         NaN
#
#        YearsCode  YearsCodePro  \
# 0           36.0          27.0
# 1            7.0           4.0
# 2            4.0           NaN
# 3            7.0           4.0
# 4           15.0           8.0
# ...          ...           ...
# 64456       10.0           NaN
# 64457        NaN           NaN
# 64458        NaN           NaN
# 64459        NaN           NaN
# 64460        NaN           NaN
#
#                                       LanguageWorkedWith  \
# 0                                 C#;HTML/CSS;JavaScript
# 1                                       JavaScript;Swift
# 2                               Objective-C;Python;Swift
# 3                                                    NaN
# 4                                      HTML/CSS;Ruby;SQL
# ...                                                  ...
# 64456                                                NaN
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                NaN
# 64459                                           HTML/CSS
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL
#
#                                   LanguageDesireNextYear       NEWLearn  \
# 0                                 C#;HTML/CSS;JavaScript    Once a year
# 1                                           Python;Swift    Once a year
# 2                               Objective-C;Python;Swift  Once a decade
# 3                                                    NaN    Once a year
# 4                                        Java;Ruby;Scala    Once a year
# ...                                                  ...            ...
# 64456                                                NaN  Once a decade
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...            NaN
# 64458                                                NaN            NaN
# 64459                           HTML/CSS;Java;JavaScript    Once a year
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL    Once a year
#
#                                                 NEWStuck  \
# 0      Visit Stack Overflow;Go for a walk or other ph...
# 1      Visit Stack Overflow;Go for a walk or other ph...
# 2                                                    NaN
# 3                                                    NaN
# 4      Call a coworker or friend;Visit Stack Overflow...
# ...                                                  ...
# 64456                          Call a coworker or friend
# 64457                                                NaN
# 64458                                                NaN
# 64459     Call a coworker or friend;Visit Stack Overflow
# 64460  Meditate;Visit Stack Overflow;Go for a walk or...
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Employed full-time
# 2                                                    NaN
# 3                                                    NaN
# 4                                     Employed full-time
# ...                                                  ...
# 64456                                 Employed full-time
# 64457                                 Employed full-time
# 64458                                                NaN
# 64459                                 Employed full-time
# 64460                                 Employed full-time
#
#                                                  DevType  WorkWeekHrs  \
# 0      Developer, desktop or enterprise applications;...         50.0
# 1                Developer, full-stack;Developer, mobile          NaN
# 2                                                    NaN          NaN
# 3                                                    NaN         40.0
# 4                                                    NaN          NaN
# ...                                                  ...          ...
# 64456                                Senior executive/VP          NaN
# 64457                                                NaN          NaN
# 64458                                                NaN          NaN
# 64459                                                NaN          NaN
# 64460                                                NaN          NaN
#
#                       JobSat  \
# 0         Slightly satisfied
# 1          Very dissatisfied
# 2                        NaN
# 3      Slightly dissatisfied
# 4                        NaN
# ...                      ...
# 64456                    NaN
# 64457                    NaN
# 64458                    NaN
# 64459                    NaN
# 64460                    NaN
#
#                                               JobFactors  \
# 0      Languages, frameworks, and other technologies ...
# 1                                                    NaN
# 2                                                    NaN
# 3      Flex time or a flexible schedule;Office enviro...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                              NEWOvertime  \
# 0                       Often: 1-2 days per week or more
# 1                                                    NaN
# 2                                                    NaN
# 3      Occasionally: 1-2 days per quarter but less th...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                 NEWEdImpt
# 0                        Fairly important
# 1                        Fairly important
# 2                                     NaN
# 3      Not at all important/not necessary
# 4                          Very important
# ...                                   ...
# 64456                      Very important
# 64457                                 NaN
# 64458                                 NaN
# 64459                                 NaN
# 64460                Critically important
#
# [64451 rows x 20 columns]

# %%
survey_df.Age.describe()
# Out:
# count    45436.000000
# mean        30.834294
# std          9.506982
# min         10.000000
# 25%         24.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %%
survey_df.drop(survey_df[survey_df.WorkWeekHrs > 140].index, inplace=True)

# %%
survey_df.WorkWeekHrs.describe()
# Out:
# count    41002.000000
# mean        40.024395
# std         10.630010
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         43.000000
# max        140.000000
# Name: WorkWeekHrs, dtype: float64

# %%
survey_df.Gender.value_counts()
# Out:
# Man                                                            45895
# Woman                                                           3835
# Non-binary, genderqueer, or gender non-conforming                385
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           92
# Woman;Man                                                         73
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       25
# Name: Gender, dtype: int64

# %%
survey_df.to_csv('survey.csv',index='Fasle')

# %%
import pandas as pd

# %%
survey_df=pd.read_csv('survey.csv')

# %%
survey_df
# Out:
#        Unnamed: 0             Country   Age Gender  \
# 0               0             Germany   NaN    Man
# 1               1      United Kingdom   NaN    NaN
# 2               2  Russian Federation   NaN    NaN
# 3               3             Albania  25.0    Man
# 4               4       United States  31.0    Man
# ...           ...                 ...   ...    ...
# 64301       64456       United States   NaN    NaN
# 64302       64457             Morocco   NaN    NaN
# 64303       64458            Viet Nam   NaN    NaN
# 64304       64459              Poland   NaN    NaN
# 64305       64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64301  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64302                                              NaN
# 64303                        Primary/elementary school
# 64304                                              NaN
# 64305       Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                           UndergradMajor Hobbyist  Age1stCode  \
# 0      Computer science, computer engineering, or sof...      Yes        13.0
# 1      Computer science, computer engineering, or sof...       No        19.0
# 2                                                    NaN      Yes        15.0
# 3      Computer science, computer engineering, or sof...      Yes        18.0
# 4      Computer science, computer engineering, or sof...      Yes        16.0
# ...                                                  ...      ...         ...
# 64301  Computer science, computer engineering, or sof...      Yes        16.0
# 64302                                                NaN      Yes         NaN
# 64303                                                NaN      Yes         NaN
# 64304                                                NaN      Yes         NaN
# 64305  Computer science, computer engineering, or sof...      Yes         NaN
#
#        YearsCode  YearsCodePro  ...  \
# 0           36.0          27.0  ...
# 1            7.0           4.0  ...
# 2            4.0           NaN  ...
# 3            7.0           4.0  ...
# 4           15.0           8.0  ...
# ...          ...           ...  ...
# 64301       10.0           NaN  ...
# 64302        NaN           NaN  ...
# 64303        NaN           NaN  ...
# 64304        NaN           NaN  ...
# 64305        NaN           NaN  ...
#
#                                   LanguageDesireNextYear       NEWLearn  \
# 0                                 C#;HTML/CSS;JavaScript    Once a year
# 1                                           Python;Swift    Once a year
# 2                               Objective-C;Python;Swift  Once a decade
# 3                                                    NaN    Once a year
# 4                                        Java;Ruby;Scala    Once a year
# ...                                                  ...            ...
# 64301                                                NaN  Once a decade
# 64302  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...            NaN
# 64303                                                NaN            NaN
# 64304                           HTML/CSS;Java;JavaScript    Once a year
# 64305                    C#;HTML/CSS;Java;JavaScript;SQL    Once a year
#
#                                                 NEWStuck  \
# 0      Visit Stack Overflow;Go for a walk or other ph...
# 1      Visit Stack Overflow;Go for a walk or other ph...
# 2                                                    NaN
# 3                                                    NaN
# 4      Call a coworker or friend;Visit Stack Overflow...
# ...                                                  ...
# 64301                          Call a coworker or friend
# 64302                                                NaN
# 64303                                                NaN
# 64304     Call a coworker or friend;Visit Stack Overflow
# 64305  Meditate;Visit Stack Overflow;Go for a walk or...
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Employed full-time
# 2                                                    NaN
# 3                                                    NaN
# 4                                     Employed full-time
# ...                                                  ...
# 64301                                 Employed full-time
# 64302                                 Employed full-time
# 64303                                                NaN
# 64304                                 Employed full-time
# 64305                                 Employed full-time
#
#                                                  DevType WorkWeekHrs  \
# 0      Developer, desktop or enterprise applications;...        50.0
# 1                Developer, full-stack;Developer, mobile         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN        40.0
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 64301                                Senior executive/VP         NaN
# 64302                                                NaN         NaN
# 64303                                                NaN         NaN
# 64304                                                NaN         NaN
# 64305                                                NaN         NaN
#
#                       JobSat  \
# 0         Slightly satisfied
# 1          Very dissatisfied
# 2                        NaN
# 3      Slightly dissatisfied
# 4                        NaN
# ...                      ...
# 64301                    NaN
# 64302                    NaN
# 64303                    NaN
# 64304                    NaN
# 64305                    NaN
#
#                                               JobFactors  \
# 0      Languages, frameworks, and other technologies ...
# 1                                                    NaN
# 2                                                    NaN
# 3      Flex time or a flexible schedule;Office enviro...
# 4                                                    NaN
# ...                                                  ...
# 64301                                                NaN
# 64302                                                NaN
# 64303                                                NaN
# 64304                                                NaN
# 64305                                                NaN
#
#                                              NEWOvertime  \
# 0                       Often: 1-2 days per week or more
# 1                                                    NaN
# 2                                                    NaN
# 3      Occasionally: 1-2 days per quarter but less th...
# 4                                                    NaN
# ...                                                  ...
# 64301                                                NaN
# 64302                                                NaN
# 64303                                                NaN
# 64304                                                NaN
# 64305                                                NaN
#
#                                 NEWEdImpt
# 0                        Fairly important
# 1                        Fairly important
# 2                                     NaN
# 3      Not at all important/not necessary
# 4                          Very important
# ...                                   ...
# 64301                      Very important
# 64302                                 NaN
# 64303                                 NaN
# 64304                                 NaN
# 64305                Critically important
#
# [64306 rows x 21 columns]

# %%
survey_df.where(~(survey_df.Gender.str.contains(';', na=False)), np.nan, inplace=True)

# %%
import numpy as np

# %%
survey_df
# Out:
#        Unnamed: 0             Country   Age Gender  \
# 0             0.0             Germany   NaN    Man
# 1             1.0      United Kingdom   NaN    NaN
# 2             2.0  Russian Federation   NaN    NaN
# 3             3.0             Albania  25.0    Man
# 4             4.0       United States  31.0    Man
# ...           ...                 ...   ...    ...
# 64301     64456.0       United States   NaN    NaN
# 64302     64457.0             Morocco   NaN    NaN
# 64303     64458.0            Viet Nam   NaN    NaN
# 64304     64459.0              Poland   NaN    NaN
# 64305     64460.0               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64301  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64302                                              NaN
# 64303                        Primary/elementary school
# 64304                                              NaN
# 64305       Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                           UndergradMajor Hobbyist  Age1stCode  \
# 0      Computer science, computer engineering, or sof...      Yes        13.0
# 1      Computer science, computer engineering, or sof...       No        19.0
# 2                                                    NaN      Yes        15.0
# 3      Computer science, computer engineering, or sof...      Yes        18.0
# 4      Computer science, computer engineering, or sof...      Yes        16.0
# ...                                                  ...      ...         ...
# 64301  Computer science, computer engineering, or sof...      Yes        16.0
# 64302                                                NaN      Yes         NaN
# 64303                                                NaN      Yes         NaN
# 64304                                                NaN      Yes         NaN
# 64305  Computer science, computer engineering, or sof...      Yes         NaN
#
#        YearsCode  YearsCodePro  ...  \
# 0           36.0          27.0  ...
# 1            7.0           4.0  ...
# 2            4.0           NaN  ...
# 3            7.0           4.0  ...
# 4           15.0           8.0  ...
# ...          ...           ...  ...
# 64301       10.0           NaN  ...
# 64302        NaN           NaN  ...
# 64303        NaN           NaN  ...
# 64304        NaN           NaN  ...
# 64305        NaN           NaN  ...
#
#                                   LanguageDesireNextYear       NEWLearn  \
# 0                                 C#;HTML/CSS;JavaScript    Once a year
# 1                                           Python;Swift    Once a year
# 2                               Objective-C;Python;Swift  Once a decade
# 3                                                    NaN    Once a year
# 4                                        Java;Ruby;Scala    Once a year
# ...                                                  ...            ...
# 64301                                                NaN  Once a decade
# 64302  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...            NaN
# 64303                                                NaN            NaN
# 64304                           HTML/CSS;Java;JavaScript    Once a year
# 64305                    C#;HTML/CSS;Java;JavaScript;SQL    Once a year
#
#                                                 NEWStuck  \
# 0      Visit Stack Overflow;Go for a walk or other ph...
# 1      Visit Stack Overflow;Go for a walk or other ph...
# 2                                                    NaN
# 3                                                    NaN
# 4      Call a coworker or friend;Visit Stack Overflow...
# ...                                                  ...
# 64301                          Call a coworker or friend
# 64302                                                NaN
# 64303                                                NaN
# 64304     Call a coworker or friend;Visit Stack Overflow
# 64305  Meditate;Visit Stack Overflow;Go for a walk or...
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Employed full-time
# 2                                                    NaN
# 3                                                    NaN
# 4                                     Employed full-time
# ...                                                  ...
# 64301                                 Employed full-time
# 64302                                 Employed full-time
# 64303                                                NaN
# 64304                                 Employed full-time
# 64305                                 Employed full-time
#
#                                                  DevType WorkWeekHrs  \
# 0      Developer, desktop or enterprise applications;...        50.0
# 1                Developer, full-stack;Developer, mobile         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN        40.0
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 64301                                Senior executive/VP         NaN
# 64302                                                NaN         NaN
# 64303                                                NaN         NaN
# 64304                                                NaN         NaN
# 64305                                                NaN         NaN
#
#                       JobSat  \
# 0         Slightly satisfied
# 1          Very dissatisfied
# 2                        NaN
# 3      Slightly dissatisfied
# 4                        NaN
# ...                      ...
# 64301                    NaN
# 64302                    NaN
# 64303                    NaN
# 64304                    NaN
# 64305                    NaN
#
#                                               JobFactors  \
# 0      Languages, frameworks, and other technologies ...
# 1                                                    NaN
# 2                                                    NaN
# 3      Flex time or a flexible schedule;Office enviro...
# 4                                                    NaN
# ...                                                  ...
# 64301                                                NaN
# 64302                                                NaN
# 64303                                                NaN
# 64304                                                NaN
# 64305                                                NaN
#
#                                              NEWOvertime  \
# 0                       Often: 1-2 days per week or more
# 1                                                    NaN
# 2                                                    NaN
# 3      Occasionally: 1-2 days per quarter but less th...
# 4                                                    NaN
# ...                                                  ...
# 64301                                                NaN
# 64302                                                NaN
# 64303                                                NaN
# 64304                                                NaN
# 64305                                                NaN
#
#                                 NEWEdImpt
# 0                        Fairly important
# 1                        Fairly important
# 2                                     NaN
# 3      Not at all important/not necessary
# 4                          Very important
# ...                                   ...
# 64301                      Very important
# 64302                                 NaN
# 64303                                 NaN
# 64304                                 NaN
# 64305                Critically important
#
# [64306 rows x 21 columns]

# %%
survey_df.Gender.value_counts()
# Out:
# Man                                                  45895
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: Gender, dtype: int64

# %%
survey_df.sample(10)
# Out:
#        Unnamed: 0         Country   Age Gender  \
# 56925     57066.0      Bangladesh   NaN    Man
# 62349     62503.0           India   NaN    NaN
# 33859     33942.0  United Kingdom  35.0    Man
# 59844     59993.0         Germany  32.0    Man
# 44981     45088.0     South Korea   NaN    NaN
# 22560     22612.0           India  30.0    Man
# 56414     56552.0          Brazil  27.0    Man
# 4999       5003.0          Brazil  38.0    Man
# 36776     36863.0      Bangladesh  24.0    Man
# 23559     23615.0          Sweden  36.0    Man
#
#                                                  EdLevel  \
# 56925  Some college/university study without earning ...
# 62349                                                NaN
# 33859       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 59844       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 44981                                                NaN
# 22560       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 56414  Some college/university study without earning ...
# 4999     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 36776       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 23559       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           UndergradMajor Hobbyist  Age1stCode  \
# 56925  A business discipline (such as accounting, fin...      Yes        15.0
# 62349                      Web development or web design      Yes        25.0
# 33859  Computer science, computer engineering, or sof...       No        14.0
# 59844  Computer science, computer engineering, or sof...      Yes        12.0
# 44981                                                NaN       No         NaN
# 22560  Computer science, computer engineering, or sof...       No        17.0
# 56414  Computer science, computer engineering, or sof...      Yes        15.0
# 4999   Another engineering discipline (such as civil,...      Yes        13.0
# 36776  Computer science, computer engineering, or sof...      Yes        17.0
# 23559  Computer science, computer engineering, or sof...      Yes        12.0
#
#        YearsCode  YearsCodePro  ...  \
# 56925        5.0           NaN  ...
# 62349       15.0           9.0  ...
# 33859       20.0          11.0  ...
# 59844       15.0          11.0  ...
# 44981        NaN           NaN  ...
# 22560       15.0           9.0  ...
# 56414        9.0           4.0  ...
# 4999        22.0          10.0  ...
# 36776        5.0           NaN  ...
# 23559       23.0          10.0  ...
#
#                                   LanguageDesireNextYear  \
# 56925              Go;HTML/CSS;JavaScript;Kotlin;PHP;SQL
# 62349                                            R;Scala
# 33859                     HTML/CSS;JavaScript;TypeScript
# 59844                                HTML/CSS;TypeScript
# 44981                                                NaN
# 22560  Bash/Shell/PowerShell;Dart;Go;HTML/CSS;JavaScr...
# 56414                                    Dart;Python;SQL
# 4999           Bash/Shell/PowerShell;C#;Go;Python;R;Ruby
# 36776                          C#;Java;Kotlin;PHP;Python
# 23559  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#                    NEWLearn  \
# 56925           Once a year
# 62349      Every few months
# 33859  Once every few years
# 59844      Every few months
# 44981                   NaN
# 22560  Once every few years
# 56414           Once a year
# 4999   Once every few years
# 36776           Once a year
# 23559  Once every few years
#
#                                                 NEWStuck  \
# 56925  Meditate;Play games;Visit Stack Overflow;Watch...
# 62349                                                NaN
# 33859  Call a coworker or friend;Go for a walk or oth...
# 59844  Meditate;Call a coworker or friend;Visit Stack...
# 44981                                                NaN
# 22560  Call a coworker or friend;Visit Stack Overflow...
# 56414  Play games;Call a coworker or friend;Visit Sta...
# 4999   Call a coworker or friend;Visit Stack Overflow...
# 36776  Play games;Visit Stack Overflow;Watch help / t...
# 23559  Call a coworker or friend;Visit Stack Overflow...
#
#                                Employment  \
# 56925  Not employed, but looking for work
# 62349                  Employed full-time
# 33859                  Employed full-time
# 59844                  Employed full-time
# 44981                  Employed full-time
# 22560                  Employed full-time
# 56414                  Employed full-time
# 4999                   Employed full-time
# 36776                             Student
# 23559                  Employed full-time
#
#                                                  DevType WorkWeekHrs  \
# 56925  Academic researcher;Designer;Developer, back-e...         NaN
# 62349  Developer, back-end;Developer, desktop or ente...         NaN
# 33859  Developer, back-end;Developer, desktop or ente...        40.0
# 59844                               Developer, front-end        40.0
# 44981                                                NaN         NaN
# 22560                           Data or business analyst         NaN
# 56414  Developer, back-end;Developer, desktop or ente...        48.0
# 4999   Data or business analyst;Data scientist or mac...        46.0
# 36776                                                NaN         NaN
# 23559  Developer, front-end;Developer, full-stack;Dev...        40.0
#
#                                    JobSat  \
# 56925                                 NaN
# 62349                      Very satisfied
# 33859                  Slightly satisfied
# 59844                  Slightly satisfied
# 44981                                 NaN
# 22560                                 NaN
# 56414  Neither satisfied nor dissatisfied
# 4999   Neither satisfied nor dissatisfied
# 36776                                 NaN
# 23559                      Very satisfied
#
#                                               JobFactors  \
# 56925  Languages, frameworks, and other technologies ...
# 62349  Flex time or a flexible schedule;Languages, fr...
# 33859  Flex time or a flexible schedule;Office enviro...
# 59844  How widely used or impactful my work output wo...
# 44981                                                NaN
# 22560                                                NaN
# 56414  Remote work options;Financial performance or f...
# 4999   Industry that I’d be working in;Flex time or a...
# 36776  Diversity of the company or organization;Offic...
# 23559  Diversity of the company or organization;How w...
#
#                                              NEWOvertime             NEWEdImpt
# 56925                                                NaN                   NaN
# 62349  Occasionally: 1-2 days per quarter but less th...        Very important
# 33859                                              Never        Very important
# 59844  Occasionally: 1-2 days per quarter but less th...      Fairly important
# 44981                                                NaN                   NaN
# 22560                                                NaN      Fairly important
# 56414                   Often: 1-2 days per week or more        Very important
# 4999                    Often: 1-2 days per week or more      Fairly important
# 36776                                                NaN                   NaN
# 23559                  Rarely: 1-2 days per year or less  Critically important
#
# [10 rows x 21 columns]

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
survey_df.Country.nunique()
# Out:
# 183

# %%
top_countries=survey_df.Country.value_counts().head(15)
top_countries
# Out:
# United States         12371
# India                  8364
# United Kingdom         3881
# Germany                3864
# Canada                 2175
# France                 1884
# Brazil                 1804
# Netherlands            1332
# Poland                 1259
# Australia              1199
# Spain                  1157
# Italy                  1115
# Russian Federation     1085
# Sweden                  879
# Pakistan                802
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
sns.barplot(x=top_countries.index,y=top_countries)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.xlabel('Age')
plt.ylabel('Number of respondents')

plt.hist(survey_df.Age, bins=np.arange(10,80,5), color='purple');

# %%
gender_counts = survey_df.Gender.value_counts()
gender_counts
# Out:
# Man                                                  45895
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=180);

# %%
sns.countplot(y=survey_df.EdLevel)
plt.xticks(rotation=75);
plt.ylabel(None);

# %%
(survey_df.Employment.value_counts(normalize=True, ascending=True)*100).plot(kind='barh', color='g')
plt.xlabel('Percentage');

# %% [markdown]
# #### Q: In which countries do developers work the highest number of hours per week? Consider countries with more than 250 responses only.

# %%
countries_df = survey_df.groupby('Country')[['WorkWeekHrs']].mean().sort_values('WorkWeekHrs', ascending=False)

# %%
high_response_countries_df = countries_df.loc[survey_df.Country.value_counts() > 250].head(15)

# %%
high_response_countries_df
# Out:
#                WorkWeekHrs
# Country
# Iran             44.337748
# Israel           43.915094
# China            42.150000
# United States    41.802982
# Greece           41.402724
# Viet Nam         41.391667
# South Africa     41.023460
# Turkey           40.982143
# Sri Lanka        40.612245
# New Zealand      40.457551
# Belgium          40.444444
# Canada           40.208837
# Hungary          40.194340
# Bangladesh       40.097458
# India            40.090603

# %% [markdown]
# #### Q: How important is it to start young to build a career in programming?

# %%
sns.scatterplot(x='Age', y='YearsCodePro', hue='Hobbyist', data=survey_df)
plt.xlabel("Age")
plt.ylabel("Years of professional coding experience");

# %% [markdown]
# #### Q.At what Age did you first start to code?

# %%
sns.histplot(x=survey_df.Age1stCode, bins=30, kde=True);
